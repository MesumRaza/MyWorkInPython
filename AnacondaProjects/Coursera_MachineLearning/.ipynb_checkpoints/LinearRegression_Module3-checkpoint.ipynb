# %%
import numpy
import pandas
from sklearn import linear_model as lm
from sklearn.metrics import mean_squared_error

# %%
houseprice_complete=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/kc_house_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_train=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_train_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_validation=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_valid_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_test=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_test_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_set1=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_set_1_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_set2=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_set_2_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_set3=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_set_3_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})
houseprice_set4=pandas.read_csv('C:/Users/mhemani/AnacondaProjects/Coursera_MachineLearning/Week 3 Specific Datasets/wk3_kc_house_set_4_data.csv',dtype = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int})

# %%
def polynomial_sframe(feature, degree):
    # assume that degree >= 1
    # initialize the SFrame:
    poly_sframe = pandas.DataFrame()
    # and set poly_sframe['power_1'] equal to the passed feature
    poly_sframe['power_1'] = feature
    # first check if degree > 1
    if degree > 1:
        # then loop over the remaining degrees:
        # range usually starts at 0 and stops at the endpoint-1. We want it to start at 2 and stop at degree
        for power in range(2, degree+1): 
            # first we'll give the column a name:
            name = 'power_' + str(power)
            # then assign poly_sframe[name] to the appropriate power of feature
            poly_sframe[name] = list(map(lambda x:x ** power,feature))
    return poly_sframe

# %%
tmp = [1., 2., 3.]
polynomial_sframe(tmp,3)
# Out:
#    power_1  power_2  power_3
# 0      1.0      1.0      1.0
# 1      2.0      4.0      8.0
# 2      3.0      9.0     27.0

# %%
Dataset_variable=houseprice_train
Dataset = Dataset_variable.sort_values(['sqft_living', 'price'])

# %%
poly1_data = polynomial_sframe(Dataset['sqft_living'], 15)
poly1_data['price'] = Dataset['price']
# poly1_data

# %%
poly = {}
k = 1
while k < 16:
#     <dynamically create key> 
    key = k
#     <calculate value> 
    value = polynomial_sframe(Dataset['sqft_living'], k)
    poly[key] = value
    poly[key]['price'] = Dataset['price']
    k += 1
poly[15]
# Out:
#       power_1      power_2       power_3       power_4       power_5  \
# 8840    290.0      84100.0  2.438900e+07  7.072810e+09  2.051115e+12
# 6982    370.0     136900.0  5.065300e+07  1.874161e+10  6.934396e+12
# 8338    384.0     147456.0  5.662310e+07  2.174327e+10  8.349416e+12
# 2228    390.0     152100.0  5.931900e+07  2.313441e+10  9.022420e+12
# 9631    390.0     152100.0  5.931900e+07  2.313441e+10  9.022420e+12
# 5252    420.0     176400.0  7.408800e+07  3.111696e+10  1.306912e+13
# 213     430.0     184900.0  7.950700e+07  3.418801e+10  1.470084e+13
# 541     440.0     193600.0  8.518400e+07  3.748096e+10  1.649162e+13
# 5500    470.0     220900.0  1.038230e+08  4.879681e+10  2.293450e+13
# 6918    470.0     220900.0  1.038230e+08  4.879681e+10  2.293450e+13
# 1348    520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# 3081    520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# 4408    520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# ...

# %%
def get_rss(input_dataset):
    input_variable=list(input_dataset.columns.values[:-1])
    input_var_train=input_dataset[input_variable]
    output_var_train=input_dataset['price']
    linear_model=lm.LinearRegression()
    linear_model.fit(X=input_var_train,y=output_var_train)
    input_var_test= input_dataset[input_variable]
    output_var_test= input_dataset['price']
    return str(mean_squared_error(output_var_test, linear_model.predict(X=input_var_test)))

# %%
rss_frame=pandas.DataFrame(columns=['Power','RSS'])
for i,frames in poly.items():
    print (i,get_rss(frames))
    rss_frame.append({'Power': i,'RSS':get_rss(frames)},ignore_index=True)
#     rss_frame.append(['A','B'],columns=list('Power','RSS'))
rss_frame
# Out:
# 1 72431084171.3
# 2 63280548389.0
# 3 63279391579.9
# 4 63276062040.1
# 5 63277235853.7
# 6 63129702339.3
# 7 63275483128.1
# 8 65340315377.6
# 9 70159922098.2
# 10 77040626670.0
# 11 84642240197.8
# 12 91854693513.4
# 13 117132994443.0
# 14 119459353489.0
# 15 121237623066.0
# Empty DataFrame
# Columns: [Power, RSS]
# Index: []

# %%
input_variable=list(poly[15].columns.values[:-1])
input_var_train=poly1_data[input_variable]
output_var_train=poly1_data['price']
input_variable
# list(poly1_data.columns.values[:-1])
# Out:
# ['power_1',
#  'power_2',
#  'power_3',
#  'power_4',
#  'power_5',
#  'power_6',
#  'power_7',
#  'power_8',
#  'power_9',
#  'power_10',
#  'power_11',
#  'power_12',
#  'power_13',
#  'power_14',
#  'power_15']

# %%
linear_model=lm.LinearRegression()
linear_model.fit(X=input_var_train,y=output_var_train)
print (linear_model.intercept_)
print (list(zip(linear_model.coef_, input_variable)))
# Out:
# 506800.922578
# [(2.680077893972888e-77, 'power_1'), (-1.2831222987511815e-39, 'power_2'), (-1.6486971735335461e-44, 'power_3'), (-8.0493071691289846e-50, 'power_4'), (0.0, 'power_5'), (0.0, 'power_6'), (3.6286651005819432e-55, 'power_7'), (1.498074952467487e-51, 'power_8'), (5.7397448304171821e-48, 'power_9'), (1.9515834812767321e-44, 'power_10'), (5.3789708509389057e-41, 'power_11'), (9.3803561325282581e-38, 'power_12'), (-3.624783434040523e-41, 'power_13'), (4.6396840084622148e-45, 'power_14'), (-1.9650040862752037e-49, 'power_15')]

# %%
plt.plot(poly1_data['power_1'],poly1_data['price'],'.',
        poly1_data['power_1'], linear_model.predict(poly1_data[input_variable]),'-.')

# %%
input_var_test=
output_var_test=
str(mean_squared_error(output_var_test, linear_model.predict(X=input_var_test)))
# Out:
# '79626670612.1'
