# %%
import pandas as pd
import glob
import os

# %%
file='951305'

df=pd.read_csv('C:/Users/mhemani/AnacondaProjects/all_csv/'+file+'.csv',sep = '\t' ,header=None,names = ["File"])
Stats_csv=pd.DataFrame([ x.split(',') for x in df["File"].tolist()])
# Stats_csv.drop(['0','3','4','5','6','7','8','9','10'],axis=1)
# Stats_csv.columns=list(range(len(Match_csv.columns)))
# Stats_csv.rename_axis(['Type','Innings','over.ball','battingteam','batsman','non-striker','bowler','batsman_run','extras','out_type','out_by']
Stats_csv.columns=list(range(len(Stats_csv.columns)))
Stats_csv.rename_axis({'1':'Type','2':'Innings','3':'over.ball','4':'battingteam','5':'batsman','6':'non-striker','7':'bowler','8':'batsman_run','9':'extras','10':'out_type','11':'out_by'}, axis="columns")
#Stats_csv.columns=[headerlist]
# Stats_csv[1:]
# Stats_csv=Stats_csv[Stats_csv['Type']=='ball']
# Stats_csv=Stats_csv.reset_index()
# Stats_csv['ball_id']=Stats_csv.index+1
Stats_csv
# Stats_csv_T=Stats_csv.T[1:]
# Stats_csv_T[:2]
# Stats_csv_T.columns=Stats_csv_T.iloc[0]
# cols=pd.Series(Stats_csv_T.columns)
# for dup in Stats_csv_T.columns.get_duplicates(): cols[Stats_csv_T.columns.get_loc(dup)]=[dup+str(d_idx) if d_idx!=0 else dup for d_idx in range(Stats_csv_T.columns.get_loc(dup).sum())]
# Stats_csv_T.columns=cols
# Stats_csv_T[1:][:1]
# Out:
#           0                1                                      2   \
# 0    version            1.3.0                                   None
# 1       info             team                              Hong Kong
# 2       info             team                               Zimbabwe
# 3       info           gender                                   male
# 4       info           season                                2015/16
# 5       info             date                             2016/03/08
# 6       info      competition                     ICC World Twenty20
# 7       info     match_number                                      1
# 8       info            venue  "Vidarbha Cricket Association Stadium
# 9       info             city                                 Nagpur
# 10      info     neutralvenue                                   true
# 11      info      toss_winner                              Hong Kong
# 12      info    toss_decision                                  field
# 13      info  player_of_match                              V Sibanda
# 14      info           umpire                              Aleem Dar
# 15      info           umpire                               IJ Gould
# 16      info   reserve_umpire                         RK Illingworth
# 17      info        tv_umpire                              M Erasmus
# 18      info    match_referee                              J Srinath
# 19      info           winner                               Zimbabwe
# 20      info      winner_runs                                     14
# 21      ball                1                                    0.1
# 22      ball                1                                    0.2
# 23      ball                1                                    0.3
# 24      ball                1                                    0.4
# 25      ball                1                                    0.5
# 26      ball                1                                    0.6
# 27      ball                1                                    1.1
# 28      ball                1                                    1.2
# 29      ball                1                                    1.3
# ..       ...              ...                                    ...
# 238     ball                2                                   15.2
# 239     ball                2                                   15.3
# 240     ball                2                                   15.4
# 241     ball                2                                   15.5
# 242     ball                2                                   15.6
# 243     ball                2                                   16.1
# 244     ball                2                                   16.2
# 245     ball                2                                   16.3
# 246     ball                2                                   16.4
# 247     ball                2                                   16.5
# 248     ball                2                                   16.6
# 249     ball                2                                   17.1
# 250     ball                2                                   17.2
# 251     ball                2                                   17.3
# 252     ball                2                                   17.4
# 253     ball                2                                   17.5
# 254     ball                2                                   17.6
# 255     ball                2                                   18.1
# 256     ball                2                                   18.2
# 257     ball                2                                   18.3
# 258     ball                2                                   18.4
# 259     ball                2                                   18.5
# 260     ball                2                                   18.6
# 261     ball                2                                   18.7
# 262     ball                2                                   19.1
# 263     ball                2                                   19.2
# 264     ball                2                                   19.3
# 265     ball                2                                   19.4
# 266     ball                2                                   19.5
# 267     ball                2                                   19.6
#
#             3              4              5             6     7     8   \
# 0         None           None           None          None  None  None
# 1         None           None           None          None  None  None
# 2         None           None           None          None  None  None
# 3         None           None           None          None  None  None
# 4         None           None           None          None  None  None
# 5         None           None           None          None  None  None
# 6         None           None           None          None  None  None
# 7         None           None           None          None  None  None
# 8      Jamtha"           None           None          None  None  None
# 9         None           None           None          None  None  None
# 10        None           None           None          None  None  None
# 11        None           None           None          None  None  None
# 12        None           None           None          None  None  None
# 13        None           None           None          None  None  None
# 14        None           None           None          None  None  None
# 15        None           None           None          None  None  None
# 16        None           None           None          None  None  None
# 17        None           None           None          None  None  None
# 18        None           None           None          None  None  None
# 19        None           None           None          None  None  None
# 20        None           None           None          None  None  None
# 21    Zimbabwe    H Masakadza      V Sibanda  Tanwir Afzal     0     0
# 22    Zimbabwe    H Masakadza      V Sibanda  Tanwir Afzal     0     0
# 23    Zimbabwe    H Masakadza      V Sibanda  Tanwir Afzal     0     0
# 24    Zimbabwe    H Masakadza      V Sibanda  Tanwir Afzal     0     0
# 25    Zimbabwe    H Masakadza      V Sibanda  Tanwir Afzal     1     0
# 26    Zimbabwe      V Sibanda    H Masakadza  Tanwir Afzal     0     0
# 27    Zimbabwe    H Masakadza      V Sibanda  Haseeb Amjad     0     0
# 28    Zimbabwe    H Masakadza      V Sibanda  Haseeb Amjad     0     0
# 29    Zimbabwe    H Masakadza      V Sibanda  Haseeb Amjad     4     0
# ..         ...            ...            ...           ...   ...   ...
# 238  Hong Kong    JJ Atkinson  Anshuman Rath    TL Chatara     6     0
# 239  Hong Kong    JJ Atkinson  Anshuman Rath    TL Chatara     4     0
# 240  Hong Kong    JJ Atkinson  Anshuman Rath    TL Chatara     1     0
# 241  Hong Kong  Anshuman Rath    JJ Atkinson    TL Chatara     0     0
# 242  Hong Kong  Anshuman Rath    JJ Atkinson    TL Chatara     4     0
# 243  Hong Kong    JJ Atkinson  Anshuman Rath   DT Tiripano     2     0
# 244  Hong Kong    JJ Atkinson  Anshuman Rath   DT Tiripano     0     0
# 245  Hong Kong  Anshuman Rath   Tanwir Afzal   DT Tiripano     3     0
# 246  Hong Kong   Tanwir Afzal  Anshuman Rath   DT Tiripano     4     0
# 247  Hong Kong   Tanwir Afzal  Anshuman Rath   DT Tiripano     2     0
# 248  Hong Kong   Tanwir Afzal  Anshuman Rath   DT Tiripano     3     0
# 249  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     0     0
# 250  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     0     0
# 251  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     2     0
# 252  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     0     0
# 253  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     6     0
# 254  Hong Kong   Tanwir Afzal  Anshuman Rath  T Panyangara     1     0
# 255  Hong Kong   Tanwir Afzal  Anshuman Rath    TL Chatara     1     0
# 256  Hong Kong  Anshuman Rath   Tanwir Afzal    TL Chatara     0     0
# 257  Hong Kong   Nizakat Khan   Tanwir Afzal    TL Chatara     0     0
# 258  Hong Kong   Tanwir Afzal     Aizaz Khan    TL Chatara     4     1
# 259  Hong Kong   Tanwir Afzal     Aizaz Khan    TL Chatara     1     0
# 260  Hong Kong     Aizaz Khan   Tanwir Afzal    TL Chatara     0     0
# 261  Hong Kong     Aizaz Khan   Tanwir Afzal    TL Chatara     0     0
# 262  Hong Kong   Tanwir Afzal     Aizaz Khan   DT Tiripano     1     0
# 263  Hong Kong     Aizaz Khan   Tanwir Afzal   DT Tiripano     0     1
# 264  Hong Kong   Tanwir Afzal     Aizaz Khan   DT Tiripano     0     0
# 265  Hong Kong   Tanwir Afzal     Aizaz Khan   DT Tiripano     0     0
# 266  Hong Kong   Tanwir Afzal     Aizaz Khan   DT Tiripano     2     0
# 267  Hong Kong   Tanwir Afzal     Aizaz Khan   DT Tiripano     4     0
#
#          9              10
# 0      None           None
# 1      None           None
# 2      None           None
# 3      None           None
# 4      None           None
# 5      None           None
# 6      None           None
# 7      None           None
# 8      None           None
# 9      None           None
# 10     None           None
# 11     None           None
# 12     None           None
# 13     None           None
# 14     None           None
# 15     None           None
# 16     None           None
# 17     None           None
# 18     None           None
# 19     None           None
# 20     None           None
# 21       ""             ""
# 22       ""             ""
# 23       ""             ""
# 24       ""             ""
# 25       ""             ""
# 26       ""             ""
# 27       ""             ""
# 28       ""             ""
# 29       ""             ""
# ..      ...            ...
# 238      ""             ""
# 239      ""             ""
# 240      ""             ""
# 241      ""             ""
# 242      ""             ""
# 243      ""             ""
# 244  caught    JJ Atkinson
# 245      ""             ""
# 246      ""             ""
# 247      ""             ""
# 248      ""             ""
# 249      ""             ""
# 250      ""             ""
# 251      ""             ""
# 252      ""             ""
# 253      ""             ""
# 254      ""             ""
# 255      ""             ""
# 256  caught  Anshuman Rath
# 257  caught   Nizakat Khan
# 258      ""             ""
# 259      ""             ""
# 260      ""             ""
# 261      ""             ""
# 262      ""             ""
# 263      ""             ""
# 264      ""             ""
# 265      ""             ""
# 266      ""             ""
# 267      ""             ""
#
# [268 rows x 11 columns]
