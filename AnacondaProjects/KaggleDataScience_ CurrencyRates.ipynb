# %%
import pandas
from forex_python.converter import CurrencyRates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-8adc1ab05124> in <module>()
#       1 import pandas
# ----> 2 from forex_python.converter import CurrencyRates
#
# ModuleNotFoundError: No module named 'forex_python'

# %%
currency_rates=pandas.read_csv('D:/Courses and Certifications/DataSets/Kaggle2017_Survey_DataScience/conversionRates.csv')

# %%
currency_rates=currency_rates[['originCountry','exchangeRate']]
currency_rates
# Out:
#    originCountry  exchangeRate
# 0            USD      1.000000
# 1            EUR      1.195826
# 2            INR      0.015620
# 3            GBP      1.324188
# 4            BRL      0.321350
# 5            RUB      0.017402
# 6            CAD      0.823688
# 7            AUD      0.802310
# 8            JPY      0.009108
# 9            CNY      0.153000
# 10           PLN      0.281104
# 11           SGD      0.742589
# 12           ZAR      0.077002
# 13           CHF      1.043382
# 14           MXN      0.056414
# 15           TWD      0.033304
# 16           COP      0.000342
# 17           PKR      0.009476
# 18           TRY      0.291780
# 19           DKK      0.160730
# 20           IDR      0.000076
# 21           KRW      0.000886
# 22           PHP      0.019637
# 23           IRR      0.000030
# 24           SEK      0.125204
# 25           HUF      0.003896
# 26           NZD      0.727801
# 27           CZK      0.045820
# 28           ILS      0.282974
# ...
